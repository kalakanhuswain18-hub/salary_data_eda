# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns 
import numpy as np 

data=pd.read_csv("salary_data .csv")
data
# Out:
#     Experience  Salary
# 0            1   30000
# 1            2   35000
# 2            3   40000
# 3            4   45000
# 4            5   50000
# 5            6   55000
# 6            7   60000
# 7            8   65000
# 8            9   70000
# 9           10   75000
# 10          11   80000
# 11          12   85000
# 12          13   90000
# 13          14   95000
# 14          15  100000
# 15          16  105000
# 16          17  110000
# 17          18  115000
# 18          19  120000
# 19          20  125000

# %%
sns.scatterplot(x="Experience" ,y="Salary" ,data=data , marker="d" ,sizes=(10,12) ,color="green" ,edgecolor="black" ,alpha=0.6 )
plt.show()
